# %% [markdown]
# ### Business Problem and Stakeholders
#
# The focus:
# - business pain point
# - stakeholder groups
# - decision points
# - success metrics
# - constraints and risks

# %% [markdown]
# ## Core questions
#
# 1. What business problem are we solving?
# 2. What decision should the model support?
# 3. Who uses the output?
# 4. What does a good decision look like?

# %%
from pathlib import Path

project_root = Path.cwd().resolve().parents[0]
project_root
# Out:
# PosixPath('/Users/ememakpan/Documents/New project/applied_ai_economics_portfolio/project_01_ai_credit_risk_platform')
