# %% [markdown]
# # Business Understanding and Target Definition
#
# Translate the business problem into a measurable analytical objective.
#
# Document:
# - target definition
# - acceptable proxies
# - approval, review, and rejection logic
# - evaluation metrics tied to business value

# %% [markdown]
# ## Notes
#
# - A strong ranking model is not enough on its own.
# - Calibration matters because probability estimates will be used in threshold decisions.
# - Expected loss and approval tradeoffs should be tracked alongside ML metrics.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().resolve().parents[0]
src_dir = project_root / 'src'
if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

business_metrics = {
    "default_rate": None,
    "approval_rate": None,
    "expected_loss": None,
    "recall_for_defaults": None,
    "calibration_quality": None,
}
business_metrics
# Out:
# {'default_rate': None,
#  'approval_rate': None,
#  'expected_loss': None,
#  'recall_for_defaults': None,
#  'calibration_quality': None}
